# %% [markdown]
# # TITANIC SURVIVAL PREDICTION

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
#loading the dataset
titanic =pd.read_csv('Titanic-Dataset.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass    Surname Prefix  \
# 0            1.0       0.0     3.0     Braund     Mr
# 1            2.0       1.0     1.0    Cumings    Mrs
# 2            3.0       1.0     3.0  Heikkinen   Miss
# 3            4.0       1.0     1.0   Futrelle    Mrs
# 4            5.0       0.0     3.0      Allen     Mr
# ..           ...       ...     ...        ...    ...
# 890        891.0       0.0     3.0     Dooley     Mr
# 891          NaN       NaN     NaN        NaN    NaN
# 892          NaN       NaN     NaN        NaN    NaN
# 893          NaN       NaN     NaN        NaN    NaN
# 894          NaN       NaN     NaN        NaN    NaN
#
#                                        Name  Gender  Ticket              Fare  \
# 0                               Owen Harris    Male     0.0         A/5 21171
# 1     John Bradley (Florence Briggs Thayer)    Male     0.0          PC 17599
# 2                                     Laina  Female     0.0  STON/O2. 3101282
# 3             Jacques Heath (Lily May Peel)    Male     0.0            113803
# 4                             William Henry    Male     0.0            373450
# ..                                      ...     ...     ...               ...
# 890                                 Patrick    Male     0.0            370376
# 891                                     NaN     NaN     NaN               NaN
# 892                                     NaN     NaN     NaN               NaN
# 893                                     NaN     NaN     NaN               NaN
# 894                                     NaN     NaN     NaN               NaN
#
#      Cabin Embarked Unnamed: 11
# 0     7.25        -           S
# 1    71.28      C85           C
# 2     7.93        -           S
# 3    53.10     C123           S
# 4     8.05        -           S
# ..     ...      ...         ...
# 890   7.75        -           Q
# 891    NaN      NaN         NaN
# 892    NaN      NaN         NaN
# 893    NaN      NaN         NaN
# 894    NaN      NaN         NaN
#
# [895 rows x 12 columns]

# %%
titanic.shape
# Out:
# (895, 12)

# %%
#describe the data
titanic.head()
# Out:
#    PassengerId  Survived  Pclass    Surname Prefix  \
# 0          1.0       0.0     3.0     Braund     Mr
# 1          2.0       1.0     1.0    Cumings    Mrs
# 2          3.0       1.0     3.0  Heikkinen   Miss
# 3          4.0       1.0     1.0   Futrelle    Mrs
# 4          5.0       0.0     3.0      Allen     Mr
#
#                                      Name  Gender  Ticket              Fare  \
# 0                             Owen Harris    Male     0.0         A/5 21171
# 1   John Bradley (Florence Briggs Thayer)    Male     0.0          PC 17599
# 2                                   Laina  Female     0.0  STON/O2. 3101282
# 3           Jacques Heath (Lily May Peel)    Male     0.0            113803
# 4                           William Henry    Male     0.0            373450
#
#    Cabin Embarked Unnamed: 11
# 0   7.25        -           S
# 1  71.28      C85           C
# 2   7.93        -           S
# 3  53.10     C123           S
# 4   8.05        -           S

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass    Surname Prefix  \
# 0            1.0       0.0     3.0     Braund     Mr
# 1            2.0       1.0     1.0    Cumings    Mrs
# 2            3.0       1.0     3.0  Heikkinen   Miss
# 3            4.0       1.0     1.0   Futrelle    Mrs
# 4            5.0       0.0     3.0      Allen     Mr
# ..           ...       ...     ...        ...    ...
# 890        891.0       0.0     3.0     Dooley     Mr
# 891          NaN       NaN     NaN        NaN    NaN
# 892          NaN       NaN     NaN        NaN    NaN
# 893          NaN       NaN     NaN        NaN    NaN
# 894          NaN       NaN     NaN        NaN    NaN
#
#                                        Name  Gender  Ticket              Fare  \
# 0                               Owen Harris    Male     0.0         A/5 21171
# 1     John Bradley (Florence Briggs Thayer)    Male     0.0          PC 17599
# 2                                     Laina  Female     0.0  STON/O2. 3101282
# 3             Jacques Heath (Lily May Peel)    Male     0.0            113803
# 4                             William Henry    Male     0.0            373450
# ..                                      ...     ...     ...               ...
# 890                                 Patrick    Male     0.0            370376
# 891                                     NaN     NaN     NaN               NaN
# 892                                     NaN     NaN     NaN               NaN
# 893                                     NaN     NaN     NaN               NaN
# 894                                     NaN     NaN     NaN               NaN
#
#      Cabin Embarked Unnamed: 11
# 0     7.25        -           S
# 1    71.28      C85           C
# 2     7.93        -           S
# 3    53.10     C123           S
# 4     8.05        -           S
# ..     ...      ...         ...
# 890   7.75        -           Q
# 891    NaN      NaN         NaN
# 892    NaN      NaN         NaN
# 893    NaN      NaN         NaN
# 894    NaN      NaN         NaN
#
# [895 rows x 12 columns]>

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass      Ticket       Cabin
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.381594   32.205017
# std     257.353842    0.486592    0.836071    0.806057   49.693389
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    7.915000
# 50%     446.000000    0.000000    3.000000    0.000000   14.450000
# 75%     668.500000    1.000000    3.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000    6.000000  512.330000

# %% [markdown]
# # Data Visualization

# %%
titanic["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 890      Male
# 891       NaN
# 892       NaN
# 893       NaN
# 894       NaN
# Name: Gender, Length: 895, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert labels to strings
titanic['Pclass'] = titanic['Pclass'].astype(str)

# Plot the countplot
sns.countplot(x=titanic['Survived'], hue=titanic['Pclass'])
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
titanic = titanic.join(ports)
titanic.drop(['Embarked'],axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 titanic = titanic.join(ports)
#       2 titanic.drop(['Embarked'],axis = 1, inplace = True)
#
# NameError: name 'ports' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert labels to strings
titanic['Pclass'] = titanic['Pclass'].astype(str)

# Plot the countplot
sns.countplot(x=titanic['Survived'], hue=titanic['Pclass'])
plt.show()

# %%
titanic.head()
# Out:
#    PassengerId  Survived Pclass    Surname Prefix  \
# 0          1.0       0.0    3.0     Braund     Mr
# 1          2.0       1.0    1.0    Cumings    Mrs
# 2          3.0       1.0    3.0  Heikkinen   Miss
# 3          4.0       1.0    1.0   Futrelle    Mrs
# 4          5.0       0.0    3.0      Allen     Mr
#
#                                      Name  Gender  Ticket              Fare  \
# 0                             Owen Harris    Male     0.0         A/5 21171
# 1   John Bradley (Florence Briggs Thayer)    Male     0.0          PC 17599
# 2                                   Laina  Female     0.0  STON/O2. 3101282
# 3           Jacques Heath (Lily May Peel)    Male     0.0            113803
# 4                           William Henry    Male     0.0            373450
#
#    Cabin Embarked Unnamed: 11
# 0   7.25        -           S
# 1  71.28      C85           C
# 2   7.93        -           S
# 3  53.10     C123           S
# 4   8.05        -           S

# %%
titanic.Gender = titanic.Gender.map({'Male':0,'Female':1})

# %%
titanic.drop(['Cabin','Ticket','Name'],axis = 1, inplace = True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    float64
#  1   Survived     891 non-null    float64
#  2   Pclass       895 non-null    object
#  3   Surname      891 non-null    object
#  4   Prefix       891 non-null    object
#  5   Gender       864 non-null    float64
#  6   Fare         891 non-null    object
#  7   Embarked     891 non-null    object
#  8   Unnamed: 11  891 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 63.1+ KB

# %%
titanic.isnull().values.any()
# Out:
# True

# %%
titanic[pd.isnull(titanic).any(axis = 1)]
# Out:
#      PassengerId  Survived Pclass           Surname         Prefix  Gender  \
# 30          31.0       0.0    1.0         Uruchurtu            Don     NaN
# 149        150.0       0.0    2.0             Byles            Rev     NaN
# 150        151.0       0.0    2.0           Bateman            Rev     NaN
# 245        246.0       0.0    1.0           Minahan             Dr     NaN
# 249        250.0       0.0    2.0            Carter            Rev     NaN
# 317        318.0       0.0    2.0          Moraweck             Dr     NaN
# 369        370.0       1.0    1.0            Aubart            Mme     NaN
# 398        399.0       0.0    2.0              Pain             Dr     NaN
# 443        444.0       1.0    2.0          Reynaldo             Ms     NaN
# 449        450.0       1.0    1.0           Peuchen          Major     NaN
# 536        537.0       0.0    1.0              Butt          Major     NaN
# 556        557.0       1.0    1.0       Duff Gordon           Lady     NaN
# 599        600.0       1.0    1.0       Duff Gordon            Sir     NaN
# 626        627.0       0.0    2.0          Kirkland            Rev     NaN
# 632        633.0       1.0    1.0  Stahelin-Maeglin             Dr     NaN
# 641        642.0       1.0    1.0          Sagesser           Mlle     NaN
# 647        648.0       1.0    1.0   Simonius-Blumer            Col     NaN
# 660        661.0       1.0    1.0        Frauenthal             Dr     NaN
# 694        695.0       0.0    1.0              Weir            Col     NaN
# 710        711.0       1.0    1.0             Mayne           Mlle     NaN
# 745        746.0       0.0    1.0            Crosby           Capt     NaN
# 759        760.0       1.0    1.0            Rothes   the Countess     NaN
# 766        767.0       0.0    1.0             Brewe             Dr     NaN
# 796        797.0       1.0    1.0            Leader             Dr     NaN
# 822        823.0       0.0    1.0          Reuchlin       Jonkheer     NaN
# 848        849.0       0.0    2.0            Harper            Rev     NaN
# 886        887.0       0.0    2.0          Montvila            Rev     NaN
# 891          NaN       NaN    nan               NaN            NaN     NaN
# 892          NaN       NaN    nan               NaN            NaN     NaN
# 893          NaN       NaN    nan               NaN            NaN     NaN
# 894          NaN       NaN    nan               NaN            NaN     NaN
#
#             Fare Embarked Unnamed: 11
# 30      PC 17601        -           C
# 149       244310        -           S
# 150  S.O.P. 1166        -           S
# 245        19928      C78           Q
# 249       244252        -           S
# 317        29011        -           S
# 369     PC 17477      B35           C
# 398       244278        -           S
# 443       230434        -           S
# 449       113786     C104           S
# 536       113050      B38           S
# 556        11755      A16           C
# 599     PC 17485      A20           C
# 626       219533        -           Q
# 632        13214      B50           C
# 641     PC 17477      B35           C
# 647        13213      A26           C
# 660     PC 17611        -           S
# 694       113800        -           S
# 710     PC 17482      C90           C
# 745    WE/P 5735      B22           S
# 759       110152      B77           S
# 766       112379        -           C
# 796        17465      D17           S
# 822        19972        -           S
# 848       248727        -           S
# 886       211536        -           S
# 891          NaN      NaN         NaN
# 892          NaN      NaN         NaN
# 893          NaN      NaN         NaN
# 894          NaN      NaN         NaN

# %%
#define Target variables x and y
X= titanic.Survived.copy()
Y= titanic.drop(['Survived'],axis =1 )

# %%
import pandas as pd

# Load the Titanic dataset into a DataFrame
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# Access the 'Gender' column and compute its value counts
gender_counts = titanic_data['Gender'].value_counts()

# Print the value counts
print(gender_counts)
# Out:
# Gender
# Male       682
# Female     182
# Unknown     27
# Name: count, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 895 entries, 0 to 894
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
# tarin test and split
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(X,Y, test_size = 0.2, random_state =7)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
X_train.shape, X_valid.shape, Y_train.shape, Y_valid.shape
# Out:
# ((716,), (179,), (716, 8), (179, 8))

# %%
#learning model for classification
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier()

# %%
model= LogisticRegression()

# %%
model
# Out:
# LogisticRegression()
